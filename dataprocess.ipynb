# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
import numpy as np

# %%
# 列出所有的matplotlib有的颜色
# for name, hex in matplotlib.colors.cnames.items():
    # print(name, hex)
print(len(matplotlib.colors.cnames))
# Out:
# 148

# %%
all_loss = {}
accuracy = {}
sort_accuracy = {}

# %%
all_loss['LeNet'] = [1.6242144256544204, 1.31352958249039, 1.1847674048107095, 1.0951759464757533, 1.0312513256027236, 0.9760023163094097, 0.9317566171641237, 0.8888657108683351, 0.851712247841799, 0.8184668843134504, 0.7859083576722551, 0.7644560352320559, 0.7326112778157816, 0.7069267691783393, 0.6854747742204733, 0.6642881736340465, 0.6426100643186026, 0.6204320310554822, 0.6023138596873518, 0.5891161807839563]
accuracy['LeNet'] = [0.47634, 0.57336, 0.61238, 0.62712, 0.66916, 0.6842, 0.68662, 0.7085, 0.73304, 0.7478, 0.73412, 0.7546, 0.76134, 0.77652, 0.79072, 0.77714, 0.80508, 0.80592, 0.79098, 0.8204]
sort_accuracy['LeNet'] = [0.8550247116968699, 0.9040880503144654, 0.7291338582677165, 0.7156105100463679, 0.8411949685534591, 0.688135593220339, 0.8456692913385827, 0.8050847457627118, 0.9357366771159875, 0.8855799373040752]

# %%
all_loss['AlexNet'] = [1.6470382594177528, 1.2535949297921443, 1.0847475018855173, 0.9779244823785295, 0.8868776897513097, 0.8185919923463542, 0.7630485494740865, 0.712278577117148, 0.6728370328667983, 0.6266675178945942, 0.5853622808280238, 0.5530675600163081, 0.5216182161763702, 0.48412983791613073, 0.47559833306859717, 0.4513656324656324, 0.4125896211587231, 0.39553951881992766, 0.37599814571654727, 0.3764796929466118]
accuracy['AlexNet'] = [0.4927, 0.588, 0.67408, 0.70754, 0.72952, 0.75498, 0.7811, 0.77366, 0.8081, 0.79696, 0.82704, 0.83872, 0.84712, 0.8661, 0.8742, 0.86808, 0.8815, 0.88648, 0.88684, 0.88756]
sort_accuracy['AlexNet'] = [0.9159802306425041, 0.9119496855345912, 0.8267716535433071, 0.7372488408037094, 0.8915094339622641, 0.8101694915254237, 0.9700787401574803, 0.888135593220339, 0.9780564263322884, 0.9482758620689655]

# %%
all_loss['VGG11'] = [1.2797923941720546, 0.8204267419688761, 0.6319287241801801, 0.5093692947448406, 0.3947184955271024, 0.30049776959918817, 0.22226405595217713, 0.1716289870436193, 0.12499573790278794, 0.10720912222238049, 0.08451989348654552, 0.07376416784010903, 0.06238203229706184, 0.05902868207292414, 0.054739658074399546, 0.046656431376819574, 0.0440141692180995, 0.040774361139257746, 0.037835499233601716, 0.038758098736319496]
accuracy['VGG11'] = [0.69674, 0.76524, 0.81788, 0.8647, 0.91078, 0.93784, 0.95356, 0.97072, 0.97222, 0.96346, 0.98072, 0.97492, 0.983, 0.98192, 0.9873, 0.98874, 0.98556, 0.99128, 0.98768, 0.99384]
sort_accuracy['VGG11'] = [1.0, 0.9921383647798742, 0.9921259842519685, 0.9953632148377125, 0.9874213836477987, 0.988135593220339, 0.9984251968503937, 0.9966101694915255, 0.9952978056426333, 0.9984326018808778]

# %%
all_loss['VGG13'] = [1.2642371852684509, 0.7722501971989947, 0.5903376623264054, 0.4784044684923213, 0.3800432443847437, 0.30268731431278123, 0.23576976750951137, 0.18087512682027676, 0.1408744841037542, 0.10939275374864717, 0.08912606567770834, 0.07885368761744664, 0.0641673685397174, 0.059465244257598734, 0.05032006161191555, 0.05069959139102436, 0.0446176283173007, 0.04227883966442089, 0.038349986351278245, 0.035195458980138435]
accuracy['VGG13'] = [0.6891, 0.77314, 0.83566, 0.88822, 0.90306, 0.92948, 0.93804, 0.96178, 0.97378, 0.97418, 0.97518, 0.98266, 0.98802, 0.9846, 0.98568, 0.98912, 0.99238, 0.9936, 0.99396, 0.98878]
sort_accuracy['VGG13'] = [0.9857142857142858, 0.9910714285714286, 0.9846153846153847, 0.9775641025641025, 0.9801980198019802, 0.9935275080906149, 0.9819819819819819, 0.9933110367892977, 0.9866220735785953, 1.0]

# %%
all_loss['VGG16'] = [1.4878040287653198, 0.9365591992959952, 0.7370820180763065, 0.6060846281783355, 0.5078294051958777, 0.4291884641894294, 0.3603880833024564, 0.2933719548994623, 0.24789767926725584, 0.198568012527264, 0.1621592563060124, 0.1343770895839271, 0.11871750627541938, 0.0996952341926639, 0.08778401462586306, 0.0753310109254049, 0.06421501902134522, 0.06112010521195529, 0.0573385018331911, 0.0516717257278869]
accuracy['VGG16'] = [0.61826, 0.72454, 0.79506, 0.81732, 0.84844, 0.88578, 0.90558, 0.92866, 0.93832, 0.9508, 0.95308, 0.96834, 0.97676, 0.95392, 0.98222, 0.98524, 0.98964, 0.98392, 0.98868, 0.98892]
sort_accuracy['VGG16'] = [0.9821428571428571, 1.0, 0.9907692307692307, 0.9871794871794872, 0.9966996699669967, 0.9935275080906149, 0.993993993993994, 0.9832775919732442, 0.9899665551839465, 1.0]

# %%
all_loss['VGG19'] = [1.7686422246191509, 1.193289189539907, 0.9002916185599764, 0.7483896711826934, 0.6286251023221199, 0.5321085340417254, 0.4624791795297352, 0.38920851096587106, 0.33552453419684297, 0.2911587263483678, 0.24505771608913646, 0.20557330978696076, 0.1741280048142385, 0.14644487293513345, 0.1290046954908601, 0.11228246268544756, 0.09866908017803183, 0.08531898694664307, 0.08279588602601176, 0.0675076813722277]
accuracy['VGG19'] = [0.4279, 0.66604, 0.7312, 0.77616, 0.82448, 0.84562, 0.87258, 0.90588, 0.9072, 0.93078, 0.94332, 0.95704, 0.95202, 0.9642, 0.97252, 0.9682, 0.97178, 0.97656, 0.97264, 0.98384]
sort_accuracy['VGG19'] = [0.9964285714285714, 0.9821428571428571, 0.9723076923076923, 0.9166666666666666, 0.9933993399339934, 0.9805825242718447, 0.984984984984985, 0.9899665551839465, 0.9966555183946488, 1.0]

# %%
all_loss['GoogLeNet'] = [1.2311952696431934, 0.7666956804063924, 0.578668496149885, 0.4777612447205102, 0.3925454377594506, 0.3375073971079134, 0.2815402130908368, 0.23534502303394514, 0.19595492798406297, 0.16418727704554872, 0.14072739037082477, 0.11543235368431186, 0.10002748314839076, 0.08524505978824137, 0.08325784758050138, 0.06983265248925218, 0.06453105599111508, 0.058409628307665974, 0.05595131519743625, 0.05454142128511587]
accuracy['GoogLeNet'] = [0.68024, 0.78884, 0.84078, 0.87326, 0.88924, 0.90944, 0.92276, 0.93896, 0.94442, 0.95026, 0.9642, 0.96864, 0.97296, 0.97084, 0.97456, 0.97932, 0.98056, 0.98624, 0.98712, 0.98292]
sort_accuracy['GoogLeNet'] = [0.9892857142857143, 0.9970238095238095, 0.9723076923076923, 0.967948717948718, 0.9834983498349835, 0.970873786407767, 0.996996996996997, 0.9899665551839465, 0.9933110367892977, 0.9879518072289156]

# %%
print(len(all_loss), accuracy.keys, sort_accuracy.values, sep='\n')
# print('all_loss:', all_loss, 'accuracy:', accuracy, 'sort_accuracy', sort_accuracy, sep='\n')
# Out:
# 7
# <built-in method keys of dict object at 0x00000210C4FC2840>
# <built-in method values of dict object at 0x00000210C4FC43C0>

# %%
classes = np.array(['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])

# %%
x = np.linspace(-1, 1, 50)
y = 2 * x + 1

# %%
colors = ['wheat', 'blue', 'yellow', 'green', 'pink', 'purple', 'red']
colors = dict(zip(all_loss.keys(), colors))
print(colors)
# Out:
# {'LeNet': 'wheat', 'AlexNet': 'blue', 'VGG11': 'yellow', 'VGG13': 'green', 'VGG16': 'pink', 'VGG19': 'purple', 'GoogLeNet': 'red'}

# %%
for k, v in colors.items():
    print(k, v)
# Out:
# LeNet wheat
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple
# GoogLeNet red

# %%
epoch = np.arange(1, 21)
plt.figure(figsize=(20, 15))
plt.title('The loss of Every model with epoch')
for name, loss in all_loss.items():
    print(name, colors[name])
    plt.plot(epoch, loss, color=colors[name], label=name, linewidth=1.5)

    for x, y in zip(epoch, loss):
        plt.text(x, y, '%3s'%round(y, 2), ha='center', va='bottom')


plt.legend(loc='best')
plt.savefig('loss/all.png')
plt.show()
# Out:
# LeNet wheat
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple
# GoogLeNet red

# %%
epoch = np.arange(1, 21)
plt.figure(figsize=(29, 10))
for index, data in enumerate(all_loss.items(), 1):
    name, loss = data
    plt.subplot(2, 4, index)
    plt.title(f'The loss of model {name} with epoch')
    plt.plot(epoch, loss, color=colors[name], label=name, linewidth=1.5)
    plt.legend(loc='best')
    # plt.savefig(f'{name}.png')
    # plt.show()
plt.savefig('loss/The loss of every model with epoch')
plt.show()

# %%
epoch = np.arange(1, 21)
plt.figure(figsize=(20, 15))
plt.title('The Accuracy of Every model with epoch')
for name, rate in accuracy.items():
    print(name, colors[name])
    plt.plot(epoch, rate, color=colors[name], label=name, linewidth=1.5)

    for x, y in zip(epoch, rate):
        plt.text(x, y, '%3s'%round(y, 2), ha='center', va='bottom')


plt.legend(loc='best', borderpad=3)
plt.savefig('accuracy/all.png')
plt.show()
# Out:
# LeNet wheat
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple
# GoogLeNet red

# %%
epoch = np.arange(1, 21)
plt.figure()
plt.title('The Accuracy of Every model with epoch')
for name, rate in accuracy.items():
    print(name, colors[name])
    plt.plot(epoch, rate, color=colors[name], label=name)

plt.legend(loc='best')
plt.savefig('accuracy/all.png')
plt.show()
# Out:
# LeNet wheat
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple
# GoogLeNet red

# %%
epoch = np.arange(1, 21)
plt.figure(figsize=(29, 10))
for index, data in enumerate(accuracy.items(), 1):
    name, rate = data
    plt.subplot(2, 4, index)
    plt.title(f'The accuracy of model {name} with epoch')
    plt.plot(epoch, rate, color=colors[name], label=name, linewidth=1.5)
    plt.legend(loc='best')
    # plt.savefig(f'{name}.png')
    # plt.show()
plt.savefig('accuracy/The accuracy of every model with epoch')
plt.show()

# %%
epoch = np.arange(1, 21)
for name, rate in accuracy.items():
    plt.figure()
    plt.title(f'The Accuracy of model {name} with epoch')
    plt.plot(epoch, rate, color=colors[name], label=name)
    plt.legend(loc='best')
    plt.savefig('accuracy/%s.png'%name)
    plt.show()

# %%
models_name = list(accuracy.keys())
test_acc = np.array(list(accuracy.values()))[:, -1]

# %%
plt.figure(figsize=(30, 58))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
for index, data in enumerate(sort_accuracy.items(), 1):
    name, rate = data
    plt.subplot(4, 2, index)
    plt.title(f'The Accuracy Of Every Variety Of {name}', fontsize=40)
    plt.bar(classes, rate, color=colors[name], label=name)
    # plt.legend(loc='best')
    for x, y in zip(classes, rate):
        plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom', fontsize=20)

plt.subplot(4, 2, 8)
plt.title('The test_acc of every model', fontsize=40)
plt.bar(models_name, test_acc, color='bgry')
for x, y in zip(models_name, test_acc):
    plt.text(x, y, '%3s'%round(y, 2), ha='center', va='bottom', fontsize=20)

# plt.savefig('sort_accuracy/the accuracy of every variety.png')
plt.show()
# Out:
# <ipython-input-114-f72c0c20a658>:15: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   plt.bar(models_name, test_acc, color='bgry')

# %%
models_name = list(accuracy.keys())
test_acc = np.array(list(accuracy.values()))[:, -1]

plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.title('The test_acc of every model')
plt.bar(models_name, test_acc, color='steelblue')
for x, y in zip(models_name, test_acc):
    plt.text(x, y, '%3s'%y, ha='center', va='bottom')

plt.subplot(1, 2, 2)
plt.title('The test_acc of every model')
plt.plot(models_name, test_acc)
for x, y in zip(models_name, test_acc):
    plt.text(x, y, '%3s'%y, ha='center', va='bottom', bbox=dict(facecolor='white', alpha=1), fontsize=35)
plt.savefig('test_accuracy/test_acc.png')
plt.show()

# %%
help(plt.text)
# Out:
# Help on function text in module matplotlib.pyplot:
#
# text(x, y, s, fontdict=None, **kwargs)
#     Add text to the axes.
#
#     Add the text *s* to the axes at location *x*, *y* in data coordinates.
#
#     Parameters
#     ----------
#     x, y : float
#         The position to place the text. By default, this is in data
#         coordinates. The coordinate system can be changed using the
#         *transform* parameter.
#
#     s : str
#         The text.
#
#     fontdict : dict, default: None
#         A dictionary to override the default text properties. If fontdict
#         is None, the defaults are determined by `.rcParams`.
#
#     Returns
#     -------
#     `.Text`
#         The created `.Text` instance.
#
#     Other Parameters
#     ----------------
#     **kwargs : `~matplotlib.text.Text` properties.
#         Other miscellaneous text parameters.
#
#         Properties:
# ...

# %% [markdown]
# # 以下为实验学习代码

# %%
plt.figure()
plt.title('the accuracy of every variety of LeNet and AlexNet')
plt.bar(classes, sort_accuracy['LeNet'], color=colors['LeNet'])
# plt.bar(classes, sort_accuracy['AlexNet'], color=colors['AlexNet'])
for x, y in zip(classes, sort_accuracy['LeNet']):
    plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom')
# for x, y in zip(classes, sort_accuracy['AlexNet']):
    # plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom')
plt.show()

# %%
# plt.figure()
# plt.title('the accuracy of every variety of LeNet and AlexNet')
# plt.bar(classes, sort_accuracy['LeNet'], color=colors['LeNet'])
# # plt.bar(classes, sort_accuracy['AlexNet'], color=colors['AlexNet'])
# for x, y in zip(classes, sort_accuracy['LeNet']):
#     plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom')
# # for x, y in zip(classes, sort_accuracy['AlexNet']):
#     # plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom')
# plt.show()


for name, rate in sort_accuracy.items():
    plt.figure()
    plt.title(f'The Accuracy Of Every Variety Of {name}')
    plt.bar(classes, rate, color='rbgy', label=name)
    # plt.legend(loc='best')
    for x, y in zip(classes, rate):
        plt.text(x, y, "%3s"%round(y, 3), ha='center', va='bottom')
    # plt.savefig('sort_accuracy/%s.png'%name)
    plt.show()
# Out:
# <ipython-input-26-8ed16a6d6bef>:15: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   plt.bar(classes, rate, color='rbgy', label=name)

# %%
num_list = [1.5,0.6,7.8,6]
plt.bar(range(len(num_list)), num_list)
plt.show()

# %%
plt.figure() # 定义一个图像窗口
plt.plot(x, y)
plt.show()

# %%
epoch = np.arange(1, 21)
plt.figure()
plt.title('The loss of AlexNet')
plt.plot(epoch, all_loss['AlexNet'])
plt.show()

# %%
epoch = np.arange(1, 21)
plt.figure()
plt.title('The loss of Every model with epoch')
for name, loss in all_loss.items():
    print(name, colors[name])
    plt.plot(epoch, loss, color=colors[name], label=name, linewidth=1.5)

plt.legend(loc='best')
plt.show()
# Out:
# LeNet red
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple

# %%
epoch = np.arange(1, 21)
plt.figure()
plt.title('The Accuracy of Every model with epoch')
for name, rate in accuracy.items():
    print(name, colors[name])
    plt.plot(epoch, rate, color=colors[name], label=name)

plt.legend(loc='best')
plt.show()
# Out:
# LeNet red
# AlexNet blue
# VGG11 yellow
# VGG13 green
# VGG16 pink
# VGG19 purple
